# %%
! pip install -q torchview
! pip install -q -U graphviz
! pip install torchviz
! pip install torchinfo
! pip install numpy
# Out:
# Requirement already satisfied: torchviz in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (0.0.3)
# Requirement already satisfied: torch in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torchviz) (2.6.0)
# Requirement already satisfied: graphviz in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torchviz) (0.20.3)
# Requirement already satisfied: filelock in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (4.12.2)
# Requirement already satisfied: networkx in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (3.4.2)
# Requirement already satisfied: jinja2 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from torch->torchviz) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from sympy==1.13.1->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (from jinja2->torch->torchviz) (3.0.2)
# Requirement already satisfied: torchinfo in /home/abhi/anaconda3/envs/model_visualization/lib/python3.11/site-packages (1.8.0)
# Collecting numpy
#   Using cached numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.2.3

# %%
from torchview import draw_graph
from torch import nn
import torch
import graphviz
from torchinfo import summary

# when running on VSCode run the below command
# svg format on vscode does not give desired result
graphviz.set_jupyter_format('png')
# Out:
# 'svg'

# %%
from models_files.models import *

# %%
input_shape = (2,128)
summary(MLP(), input_shape)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLP                                      [2, 2]                    --
# ├─Sequential: 1-1                        [2, 2]                    --
# │    └─Linear: 2-1                       [2, 64]                   8,256
# │    └─ReLU: 2-2                         [2, 64]                   --
# │    └─Linear: 2-3                       [2, 32]                   2,080
# │    └─ReLU: 2-4                         [2, 32]                   --
# │    └─Linear: 2-5                       [2, 16]                   528
# │    └─ReLU: 2-6                         [2, 16]                   --
# │    └─Linear: 2-7                       [2, 8]                    136
# │    └─ReLU: 2-8                         [2, 8]                    --
# │    └─Linear: 2-9                       [2, 4]                    36
# │    └─ReLU: 2-10                        [2, 4]                    --
# │    └─Linear: 2-11                      [2, 2]                    10
# ==========================================================================================
# Total params: 11,046
# Trainable params: 11,046
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.02
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.05
# ==========================================================================================

# %%
model_graph = draw_graph(
    MLP(), input_size=(2, 128),
    graph_name='MLP',
    hide_inner_tensors=False,
    hide_module_functions=False,
    save_graph=True,
    filename="mlp_graph",
    directory="output"
)

model_graph.visual_graph
